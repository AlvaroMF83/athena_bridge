# %%
# %cd /home/sagemaker-user/athena_bridge
# %pip install -e .            # (o -e ".[test]" si defines extras)
# Out:
# /home/sagemaker-user/athena_bridge
# Obtaining file:///home/sagemaker-user/athena_bridge
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for athena_bridge (pyproject.toml) ... done
#   Created wheel for athena_bridge: filename=athena_bridge-0.0.1-0.editable-py3-none-any.whl size=6993 sha256=5abe1ff0fc4e6ce79e62a12c98e88747869e2063f50c51726d41ecaa260fd08e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7z3y8ay6/wheels/32/99/bc/4c7ada3e84e2673f4d4776e044d89dca78028a63859a1ae19e
# Successfully built athena_bridge
# ...
#   Attempting uninstall: athena_bridge
#     Found existing installation: athena_bridge 0.0.1
#     Uninstalling athena_bridge-0.0.1:
#       Successfully uninstalled athena_bridge-0.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %pip install -U pytest
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pytest]2m1/2 [pytest]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pytest tests -q
# Out:
# /opt/conda/lib/python3.12/site-packages/fs/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__("pkg_resources").declare_namespace(__name__)  # type: ignore
# ........................................................................ [ 19%]
# ........................................................................ [ 39%]
# ........................................................................ [ 58%]
# ........................................................................ [ 78%]
# ........................................................................ [ 97%]
# .........                                                                [100%]
# =============================== warnings summary ===============================
# ...
